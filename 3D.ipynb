# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import os
os.chdir(r"C:\Users\haoliang\Desktop\资格论文\data")
os.getcwd()
# Out:
# 'C:\\Users\\haoliang\\Desktop\\资格论文\\data'

# %%
df= pd.read_stata("3D.dta",convert_categoricals = False)
df.head()
# Out:
#    eduy  loginc_pa   logisei
# 0  12.0  10.496458  3.526361
# 1  16.0  10.208453  3.931826
# 2  12.0   9.392662  3.761200
# 3   9.0   9.392662  3.871201
# 4  16.0   9.392662  3.761200

# %%
fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig)
delta = 0.125
# 生成代表X轴数据的列表
x = df['loginc_pa']
# 生成代表Y轴数据的列表
y = df['eduy']
# 对x、y数据执行网格化
X, Y = np.meshgrid(x, y)
# 计算Z轴数据（高度数据）
Z = df['logisei']
# 绘制3D图形
ax.plot_surface(x, y, Z,
    rstride=1,  # rstride（row）指定行的跨度
    cstride=1,  # cstride(column)指定列的跨度
    cmap=plt.get_cmap('rainbow'))  # 设置颜色映射
# 设置Z轴范围
ax.set_zlim(-2, 2)
# 设置标题
plt.title("3D图")
#plt.savefig("d:/test.png")
plt.show()
# Out:
# C:\Users\haoliang\AppData\Local\Temp\ipykernel_26856\2286682537.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\haoliang\Desktop\资格论文\code\3D.ipynb Cell 3 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> Z = df['logisei']
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> # 绘制3D图形
# ---> <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> ax.plot_surface(x, y, Z,
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>     rstride=1,  # rstride（row）指定行的跨度
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>     cstride=1,  # cstride(column)指定列的跨度
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     cmap=plt.get_cmap('rainbow'))  # 设置颜色映射
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> # 设置Z轴范围
#      <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> ax.set_zlim(-2, 2)
#
# File c:\Users\haoliang\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File c:\Users\haoliang\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1581, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578 had_data = self.has_data()
#    1580 if Z.ndim != 2:
# -> 1581     raise ValueError("Argument Z must be 2-dimensional.")
#    1583 Z = cbook._to_unmasked_float_array(Z)
#    1584 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
x = x.to_numpy()

y = y.to_numpy()

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, Z,c=Z, cmap='Greens');

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

Argument Z must be 2-dimensional.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\haoliang\Desktop\资格论文\code\3D.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> ax = plt.axes(projection='3d')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> ax.plot_surface(x, y, Z, rstride=1, cstride=1,
#       <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>                 cmap='viridis', edgecolor='none')
#       <a href='vscode-notebook-cell:/c%3A/Users/haoliang/Desktop/%E8%B5%84%E6%A0%BC%E8%AE%BA%E6%96%87/code/3D.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> ax.set_title('surface')
#
# File c:\Users\haoliang\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File c:\Users\haoliang\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1581, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578 had_data = self.has_data()
#    1580 if Z.ndim != 2:
# -> 1581     raise ValueError("Argument Z must be 2-dimensional.")
#    1583 Z = cbook._to_unmasked_float_array(Z)
#    1584 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
